# %%
using POMDPs
using POMDPModels
using POMDPPolicies
using POMDPModelTools
using LinearAlgebra

# %%
m = SimpleGridWorld()
# Out:
# SimpleGridWorld
#   size: Tuple{Int64,Int64}
#   rewards: Dict{StaticArrays.SArray{Tuple{2},Int64,1,2},Float64}
#   terminate_from: Set{StaticArrays.SArray{Tuple{2},Int64,1,2}}
#   tprob: Float64 0.7
#   discount: Float64 0.95

# %%
render(m, NamedTuple())
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Div{Measures.Add{Measures.Length{:w,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}},Measures.Div{Measures.Add{Measures.Length{:h,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}}},Tuple{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}((1.0w + -min(1.0w, 1.0h) / 2, 1.0h + -min(1.0w, 1.0h) / 2), (min(1.0w, 1.0h), min(1.0w, 1.0h))), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(1.0mm)])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.9cx, 0.0cy), (0.1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(1.0,1.0,1.0,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.9cx, 0.1cy), (0.1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Propert ...

# %%
function policy_iterate(policy)
    T = convert(Matrix{Float64}, POMDPModelTools.policy_transition_matrix(m, policy))
    R = POMDPModelTools.policy_reward_vector(m, policy)
    V = inv(I-discount(m)*T)*R
    
    policy_vector = Vector{actiontype(m)}(undef, length(states(m)))
    for s in states(m)
        best_a = nothing
        best_q = -Inf
        for a in actions(m)
            
            # calculate E[V(s') | a]
            trans_dist = transition(m, s, a)
            exp_val = 0.0
            for sp in support(trans_dist)
                exp_val += pdf(trans_dist, sp)*V[stateindex(m, sp)]
            end
            
            q = reward(m, s, a) + discount(m)*exp_val
            
            if q > best_q
                best_q = q
                best_a = a
            end
        end
        policy_vector[stateindex(m, s)] = best_a
    end
    return VectorPolicy(m, policy_vector), V
end
# Out:
# policy_iterate (generic function with 1 method)

# %%
policy = VectorPolicy(m, fill(:right, length(states(m))))
render(m, NamedTuple(), policy=policy)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Div{Measures.Add{Measures.Length{:w,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}},Measures.Div{Measures.Add{Measures.Length{:h,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}}},Tuple{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}((1.0w + -min(1.0w, 1.0h) / 2, 1.0h + -min(1.0w, 1.0h) / 2), (min(1.0w, 1.0h), min(1.0w, 1.0h))), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(1.0mm)])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.9cx, 0.0cy), (0.1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}}(Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}[Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((0.5cx, 0.5cy), "⇨", Compose.HCenter(), Compose.VCenter(), Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(0.0, (0.5w, 0.5h)), (0.0mm, 0.0mm))], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.0,0.0,0.0,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol(""))]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64 ...

# %%
newpolicy, V = policy_iterate(policy)
c = render(m, NamedTuple(), policy=policy, color=s->V[stateindex(m, s)])
display(c)
@show policy.act == newpolicy.act
policy = newpolicy
newc = render(m, NamedTuple(), policy=policy, color=s->V[stateindex(m, s)])
display(newc)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Div{Measures.Add{Measures.Length{:w,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}},Measures.Div{Measures.Add{Measures.Length{:h,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}}},Tuple{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}((1.0w + -min(1.0w, 1.0h) / 2, 1.0h + -min(1.0w, 1.0h) / 2), (min(1.0w, 1.0h), min(1.0w, 1.0h))), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(1.0mm)])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.9cx, 0.0cy), (0.1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}}(Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}[Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((0.5cx, 0.5cy), "⇨", Compose.HCenter(), Compose.VCenter(), Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(0.0, (0.5w, 0.5h)), (0.0mm, 0.0mm))], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.0,0.0,0.0,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol(""))]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64 ...
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Div{Measures.Add{Measures.Length{:w,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}},Measures.Div{Measures.Add{Measures.Length{:h,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}}},Tuple{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}((1.0w + -min(1.0w, 1.0h) / 2, 1.0h + -min(1.0w, 1.0h) / 2), (min(1.0w, 1.0h), min(1.0w, 1.0h))), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(1.0mm)])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.9cx, 0.0cy), (0.1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}}(Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}[Compose.TextPrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}},Tuple{Measures.Length{:mm,Float64},Measures.Length{:mm,Float64}}}((0.5cx, 0.5cy), "↓", Compose.HCenter(), Compose.VCenter(), Compose.Rotation{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(0.0, (0.5w, 0.5h)), (0.0mm, 0.0mm))], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.0,0.0,0.0,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol(""))]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64 ...
# policy.act == newpolicy.act = false

# %%
include("bellman.jl")
# Out:
# bellman (generic function with 1 method)

# %%
V = zeros(length(states(m)))
render(m, NamedTuple(), color=s->V[stateindex(m, s)])
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Div{Measures.Add{Measures.Length{:w,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}},Measures.Div{Measures.Add{Measures.Length{:h,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}}},Tuple{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}((1.0w + -min(1.0w, 1.0h) / 2, 1.0h + -min(1.0w, 1.0h) / 2), (min(1.0w, 1.0h), min(1.0w, 1.0h))), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(1.0mm)])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.9cx, 0.0cy), (0.1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(1.0,1.0,1.0,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.9cx, 0.1cy), (0.1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Propert ...

# %%
Vp = bellman(m, V)
@show maximum(abs, Vp-V)
V = Vp
render(m, NamedTuple(), color=s->V[stateindex(m, s)])
# Out:
# maximum(abs, Vp - V) = 2.5313178581676254e-5
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Div{Measures.Add{Measures.Length{:w,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}},Measures.Div{Measures.Add{Measures.Length{:h,Float64},Measures.Neg{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}}},Tuple{Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Min{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}}((1.0w + -min(1.0w, 1.0h) / 2, 1.0h + -min(1.0w, 1.0h) / 2), (min(1.0w, 1.0h), min(1.0w, 1.0h))), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(1.0mm)])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.9cx, 0.0cy), (0.1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255,0.5019607843137255,1.0))]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(0.500373049220343,0.7514106691644005,0.5408098696304899,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.9cx, 0.1cy), (0.1cx, 0.1cy)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}(Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}[Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w, 0.0h), 1.0w, 1.0h)], Symbol(""))]), List([Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.5019607843137255,0.5019607843137255 ...
